# %%
rootF = 'D:/Data/Paper defocus/'

# %%
from matplotlib.pyplot import *
from matplotlib import image
from numpy import *
import os.path
import pandas as pd
from skimage import io

from scipy.interpolate import RegularGridInterpolator, interp2d
from scipy.signal import fftconvolve

from shared.CalcXYshift import *

# %% [markdown]
# ## Select eye simulation

# %%
simulation = '20210219 Mouse' 

PupVals = [ '0.80', '1.40', '2.00']
dFvals = ['+40', '+30', '+20', '+10', '+00', '-10' , '-20' , '-30', '-40']
dZvals = ['-0.192344', '-0.146303', '-0.098559', '-0.049559', '0.000000', \
                  '0.049749' , '0.099093', '0.147828', '0.195622']

SourceVals = ['1','2','3','4']

Total_count = len(PupVals) * len(dFvals) * len(SourceVals)

# Other parameters
CrossCorrAlign = 1

# Original images
ImageNbs = [1, 2, 3, 5]
ImageSuffix = '_image.png'

# %%
tot_conditions = len(PupVals) * len(dFvals) * len(SourceVals) * len(ImageNbs)
tot_time = (len(PupVals) * len(dFvals) * len(SourceVals) * len(ImageNbs) * 25 * 300) * 2

print ('Number of conditions:', tot_conditions)
print ('Stimulation time:', tot_time, 'ms')
print ('Stimulation time:', tot_time/1000, 'sec')
print ('Stimulation time:', tot_time/1000/60, 'min')
# Out:
# Number of conditions: 432
# Stimulation time: 6480000 ms
# Stimulation time: 6480.0 sec
# Stimulation time: 108.0 min

# %% [markdown]
# ## Load polychromatic PSFs

# %%
psf_path = rootF + '/Eye model simulations/mouse PSFs/'

PSF = []
PSFname = []

count = 0
for iPup in [1,2]: #range(len(PupVals)):
    for idF in range(len(dFvals)):
        for iSource in range(len(SourceVals)):
            # Load PSF
            norm_poly_psf = load(psf_path + 'pupDiam=' + str(PupVals[iPup]) +\
                                       '_dF=' + str(dFvals[idF]) +  'Source_' + str(SourceVals[iSource]) + '.npy')
            PSF.append(norm_poly_psf)
                    
            # Save name
            PSFname.append('pupDiam=' + str(PupVals[iPup]) +\
                                       '_dF=' + str(dFvals[idF]) +  'Source_' + str(SourceVals[iSource]))

            count += 1
            
PSF = array(PSF)

# %%
PSFname
# Out:
# ['pupDiam=1.40_dF=+40Source_1',
#  'pupDiam=1.40_dF=+40Source_2',
#  'pupDiam=1.40_dF=+40Source_3',
#  'pupDiam=1.40_dF=+40Source_4',
#  'pupDiam=1.40_dF=+30Source_1',
#  'pupDiam=1.40_dF=+30Source_2',
#  'pupDiam=1.40_dF=+30Source_3',
#  'pupDiam=1.40_dF=+30Source_4',
#  'pupDiam=1.40_dF=+20Source_1',
#  'pupDiam=1.40_dF=+20Source_2',
#  'pupDiam=1.40_dF=+20Source_3',
#  'pupDiam=1.40_dF=+20Source_4',
#  'pupDiam=1.40_dF=+10Source_1',
#  'pupDiam=1.40_dF=+10Source_2',
#  'pupDiam=1.40_dF=+10Source_3',
#  'pupDiam=1.40_dF=+10Source_4',
#  'pupDiam=1.40_dF=+00Source_1',
#  'pupDiam=1.40_dF=+00Source_2',
#  'pupDiam=1.40_dF=+00Source_3',
#  'pupDiam=1.40_dF=+00Source_4',
#  'pupDiam=1.40_dF=-10Source_1',
#  'pupDiam=1.40_dF=-10Source_2',
#  'pupDiam=1.40_dF=-10Source_3',
#  'pupDiam=1.40_dF=-10Source_4',
#  'pupDiam=1.40_dF=-20Source_1',
#  'pupDiam=1.40_dF=-20Source_2',
#  'pupDiam=1.40_dF=-20Source_3',
#  'pupDiam=1.40_dF=-20Source_4',
#  'pupDiam=1.40_dF=-30Source_1',
#  'pupDiam=1.40_dF=-30Source_2',
#  'pupDiam=1.40_dF=-30Source_3',
#  'pupDiam=1.40_dF=-30Source_4',
#  'pupDiam=1.40_dF=-40Source_1',
#  'pupDiam=1.40_dF=-40Source_2',
#  'pupDiam=1.40_dF=-40Source_3',
#  'pupDiam=1.40_dF=-40Source_4',
#  'pupDiam=2.00_dF=+40Source_1',
#  'pupDiam=2.00_dF=+40Source_2',
#  'pupDiam=2.00_dF=+40Source_3',
#  'pupDiam=2.00_dF=+40Source_4',
#  'pupDiam=2.00_dF=+30Source_1',
#  'pupDiam=2.00_dF=+30Source_2',
#  'pupDiam=2.00_dF=+30Source_3',
#  'pupDiam=2.00_dF=+30Source_4',
#  'pupDiam=2.00_dF=+20Source_1',
#  'pupDiam=2.00_dF=+20Source_2',
#  'pupDiam=2.00_dF=+20Source_3',
#  'pupDiam=2.00_dF=+20Source_4',
#  'pupDiam=2.00_dF=+10Source_1',
#  'pupDiam=2.00_dF=+10Source_2',
#  'pupDiam=2.00_dF=+10Source_3',
#  'pupDiam=2.00_dF=+10Source_4',
#  'pupDiam=2.00_dF=+00Source_1',
#  'pupDiam=2.00_dF=+00Source_2',
#  'pupDiam=2.00_dF=+00Source_3',
#  'pupDiam=2.00_dF=+00Source_4',
#  'pupDiam=2.00_dF=-10Source_1',
#  'pupDiam=2.00_dF=-10Source_2',
#  'pupDiam=2.00_dF=-10Source_3',
#  'pupDiam=2.00_dF=-10Source_4',
#  'pupDiam=2.00_dF=-20Source_1',
#  'pupDiam=2.00_dF=-20Source_2',
#  'pupDiam=2.00_dF=-20Source_3',
#  'pupDiam=2.00_dF=-20Source_4',
#  'pupDiam=2.00_dF=-30Source_1',
#  'pupDiam=2.00_dF=-30Source_2',
#  'pupDiam=2.00_dF=-30Source_3',
#  'pupDiam=2.00_dF=-30Source_4',
#  'pupDiam=2.00_dF=-40Source_1',
#  'pupDiam=2.00_dF=-40Source_2',
#  'pupDiam=2.00_dF=-40Source_3',
#  'pupDiam=2.00_dF=-40Source_4']

# %% [markdown]
# ## Convolve images with PSF and re-align them

# %%
images_path = rootF + '/Eye model simulations/original images/image_'

# %%
# PSF orientation
rotation = 0

# Inverting image's polarity
polarity_invertion = False

# Save realignment distances
shifts = zeros((len(PSF), 2))

D0=10
yshift_force=-10          #-10 to not use
border_thickness = 10

for iIm in ImageNbs[1:]:

    ImageFile = images_path + str(iIm) + ImageSuffix
    
    if polarity_invertion:
        oPic = imread(ImageFile)
        Pic = abs(oPic - 1)
        # imshow(Pic, cmap='Greys_r', vmin=0, vmax=1)
    else:
        Pic = imread(ImageFile)

    # UpSample image so that 1 pixel is 1 um
    f = interp2d(linspace(0, 864, 864), linspace(0, 864, 864), Pic, kind='cubic')
    iPic = f(arange(0, len(Pic), 1/3.5), arange(0, len(Pic), 1/3.5))

    for count in range(len(PSF)):
        print (count)
        print (PSFname[count])

        OptFilt = PSF[count,:,:]
        # Rotate PSF
        OptFilt = rot90(OptFilt, rotation) # 180°
        OptFilt = OptFilt / sum(OptFilt) #norm to 1

        cPic = fftconvolve(iPic,OptFilt,mode='same')
        
        # Downsample image to original size 864 x 864
        ff = interp2d(linspace(0, len(iPic), len(iPic)), linspace(0, len(iPic), len(iPic)), cPic, kind='cubic')
        convPic = ff(arange(0, len(iPic), 3.5), arange(0, len(iPic), 3.5))
        
#         # Save blurred image        
#         image.imsave(rootF + 'Documents/Myopia/Data/MEA data/inverted blurred images/Unshifted conv images/' \
#                      + 'image_' + str(iIm) + PSFname[count] + '.png', convPic)
        
        # Realign images 
        if CrossCorrAlign > 0:
            print ('Aligning image')
            print (PSFname[count][8:12], PSFname[count][-1], int(PSFname[count][16:19]))
                        
            # fixes exceptions
            if (PSFname[count][8:12] == '1.40') & (PSFname[count][-1] == '4') & \
                        (int(PSFname[count][16:19]) <= -35):
                print ('exception')
                Dval=22
            elif (PSFname[count][8:12] == '1.40') & (PSFname[count][-1] == '1') & \
                        (int(PSFname[count][16:19]) <= -35):
                print ('exception')
                Dval=22
            elif (PSFname[count][8:12] == '2.00') & (PSFname[count][-1] == '1') & \
                        (int(PSFname[count][16:19])) <= -30:
                print ('exception')
                Dval=22
            elif (PSFname[count][8:12] == '1.40') & (PSFname[count][-1] == '2') & \
                            (int(PSFname[count][16:19]) > -40):
                print ('exception')
                Dval=20
            elif (PSFname[count][8:12] == '1.40') & (PSFname[count][-1] == '3') & \
                            (int(PSFname[count][16:19]) <- 25):
                print ('exception')
                Dval = 30
            elif (PSFname[count][8:12] == '2.00') & (PSFname[count][-1] == '3') & \
                            (int(PSFname[count][16:19]) == -40):
                Dval = 20
                print ('exception')
            elif (PSFname[count][8:12] == '2.00') & (PSFname[count][-1] == '3') & \
                            (int(PSFname[count][16:19]) <= -25):
                Dval = 30
                print ('exception')
            else:
                Dval = D0
                print ('no exception')
                
            #print ('Dval = ', Dval)

            xshift, yshift = CalcXYshift(Pic,convPic,Dval,border_thickness)
            #print ('shift:', xshift)
            
            shifts[count,:] = xshift, yshift

            if yshift_force>-10:
                yshift=yshift_force

            if xshift>0:
                convPic[:, :-xshift] = convPic[:, xshift:]
                convPic[:, -xshift:] = 0
            else:
                convPic[:, -xshift:] = convPic[:, :xshift]
                convPic[:, :-xshift] = 0
        
        # cut borders to perceptually unbias perception of shift at evaluation stage
        convPic[0:border_thickness,:] = 0
        convPic[-border_thickness:,:] = 0
        convPic[:,-border_thickness:] = 0
        convPic[:,0:border_thickness] = 0
        
        # Save blurred image        
        rescaled_convPic = convPic * 255

        io.imsave(rootF + '/Eye model simulations/convolved images/image_' \
                   + str(iIm) + PSFname[count] + '.png', rescaled_convPic.astype(np.uint8))

print ('Done!')
# Out:
# C:\Users\Sarah\AppData\Local\Temp\ipykernel_11644\1113374266.py:26: DeprecationWarning: `interp2d` is deprecated!
# `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   f = interp2d(linspace(0, 864, 864), linspace(0, 864, 864), Pic, kind='cubic')
# C:\Users\Sarah\AppData\Local\Temp\ipykernel_11644\1113374266.py:27: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   iPic = f(arange(0, len(Pic), 1/3.5), arange(0, len(Pic), 1/3.5))
# 0
# pupDiam=1.40_dF=+40Source_1
# C:\Users\Sarah\AppData\Local\Temp\ipykernel_11644\1113374266.py:41: DeprecationWarning: `interp2d` is deprecated!
# `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   ff = interp2d(linspace(0, len(iPic), len(iPic)), linspace(0, len(iPic), len(iPic)), cPic, kind='cubic')
# C:\Users\Sarah\AppData\Local\Temp\ipykernel_11644\1113374266.py:42: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   convPic = ff(arange(0, len(iPic), 3.5), arange(0, len(iPic), 3.5))
# Aligning image
# 1.40 1 40
# no exception
# 3181.0992309482485 (422, 422) 422 422
# 1
# pupDiam=1.40_dF=+40Source_2
# Aligning image
# 1.40 2 40
# exception
# 1616.173400462836 (422, 421) 422 421
# 2
# pupDiam=1.40_dF=+40Source_3
# Aligning image
# 1.40 3 40
# no exception
# 3013.0376469761063 (422, 417) 422 417
# 3
# pupDiam=1.40_dF=+40Source_4
# Aligning image
# 1.40 4 40
# no exception
# 2888.4504897487573 (422, 417) 422 417
# 4
# pupDiam=1.40_dF=+30Source_1
# Aligning image
# 1.40 1 30
# no exception
# 5169.743226794861 (423, 423) 423 423
# 5
# pupDiam=1.40_dF=+30Source_2
# Aligning image
# 1.40 2 30
# exception
# 2437.9454510673236 (423, 420) 423 420
# 6
# pupDiam=1.40_dF=+30Source_3
# Aligning image
# 1.40 3 30
# no exception
# 3621.7100111152845 (423, 417) 423 417
# 7
# pupDiam=1.40_dF=+30Source_4
# Aligning image
# 1.40 4 30
# no exception
# 3301.4041847282083 (422, 418) 422 418
# 8
# pupDiam=1.40_dF=+20Source_1
# Aligning image
# 1.40 1 20
# no exception
# 7152.227187633115 (423, 423) 423 423
# 9
# pupDiam=1.40_dF=+20Source_2
# Aligning image
# 1.40 2 20
# exception
# 3648.9067927959622 (423, 420) 423 420
# 10
# pupDiam=1.40_dF=+20Source_3
# Aligning image
# 1.40 3 20
# no exception
# 4337.165696483086 (423, 419) 423 419
# 11
# pupDiam=1.40_dF=+20Source_4
# Aligning image
# 1.40 4 20
# no exception
# 3785.275430785428 (423, 419) 423 419
# 12
# pupDiam=1.40_dF=+10Source_1
# Aligning image
# 1.40 1 10
# no exception
# 7411.062413642244 (423, 423) 423 423
# 13
# pupDiam=1.40_dF=+10Source_2
# Aligning image
# 1.40 2 10
# exception
# 4714.646845823865 (423, 421) 423 421
# 14
# pupDiam=1.40_dF=+10Source_3
# Aligning image
# 1.40 3 10
# no exception
# 5143.893806107666 (423, 420) 423 420
# 15
# pupDiam=1.40_dF=+10Source_4
# Aligning image
# 1.40 4 10
# no exception
# 4276.517775759526 (423, 421) 423 421
# 16
# pupDiam=1.40_dF=+00Source_1
# Aligning image
# 1.40 1 0
# no exception
# 5248.905746504134 (423, 423) 423 423
# 17
# pupDiam=1.40_dF=+00Source_2
# Aligning image
# 1.40 2 0
# exception
# 3860.9201864599004 (423, 422) 423 422
# 18
# pupDiam=1.40_dF=+00Source_3
# Aligning image
# 1.40 3 0
# no exception
# 5218.066212116701 (423, 422) 423 422
# 19
# pupDiam=1.40_dF=+00Source_4
# Aligning image
# 1.40 4 0
# no exception
# 4549.32161430928 (423, 423) 423 423
# 20
# pupDiam=1.40_dF=-10Source_1
# Aligning image
# 1.40 1 -10
# no exception
# 3224.9394780663324 (423, 423) 423 423
# 21
# pupDiam=1.40_dF=-10Source_2
# Aligning image
# 1.40 2 -10
# exception
# 2152.7223991442124 (423, 423) 423 423
# 22
# pupDiam=1.40_dF=-10Source_3
# Aligning image
# 1.40 3 -10
# no exception
# 4063.823449961717 (423, 424) 423 424
# 23
# pupDiam=1.40_dF=-10Source_4
# Aligning image
# 1.40 4 -10
# no exception
# 3913.856458551171 (423, 425) 423 425
# 24
# pupDiam=1.40_dF=-20Source_1
# Aligning image
# 1.40 1 -20
# no exception
# 2042.3705008827715 (423, 423) 423 423
# 25
# pupDiam=1.40_dF=-20Source_2
# Aligning image
# 1.40 2 -20
# exception
# 1138.6532048961997 (423, 424) 423 424
# 26
# pupDiam=1.40_dF=-20Source_3
# Aligning image
# 1.40 3 -20
# no exception
# 2793.8688025641577 (423, 426) 423 426
# 27
# pupDiam=1.40_dF=-20Source_4
# Aligning image
# 1.40 4 -20
# no exception
# 3127.3736830646276 (423, 428) 423 428
# 28
# pupDiam=1.40_dF=-30Source_1
# Aligning image
# 1.40 1 -30
# no exception
# 1410.9325695747993 (423, 422) 423 422
# 29
# pupDiam=1.40_dF=-30Source_2
# Aligning image
# 1.40 2 -30
# exception
# 659.1073766152548 (423, 425) 423 425
# 30
# pupDiam=1.40_dF=-30Source_3
# Aligning image
# 1.40 3 -30
# exception
# 660.6601445630755 (423, 428) 423 428
# 31
# pupDiam=1.40_dF=-30Source_4
# Aligning image
# 1.40 4 -30
# no exception
# 2433.360517372551 (423, 430) 423 430
# 32
# pupDiam=1.40_dF=-40Source_1
# Aligning image
# 1.40 1 -40
# exception
# 290.4682947732864 (423, 422) 423 422
# 33
# pupDiam=1.40_dF=-40Source_2
# Aligning image
# 1.40 2 -40
# no exception
# 1182.490897794526 (423, 425) 423 425
# 34
# pupDiam=1.40_dF=-40Source_3
# Aligning image
# 1.40 3 -40
# exception
# 398.18599543108127 (423, 430) 423 430
# 35
# pupDiam=1.40_dF=-40Source_4
# Aligning image
# 1.40 4 -40
# exception
# 1006.9224638037591 (423, 432) 423 432
# 36
# pupDiam=2.00_dF=+40Source_1
# Aligning image
# 2.00 1 40
# no exception
# 2944.205521066921 (423, 423) 423 423
# 37
# pupDiam=2.00_dF=+40Source_2
# Aligning image
# 2.00 2 40
# no exception
# 3099.660857394869 (423, 419) 423 419
# 38
# pupDiam=2.00_dF=+40Source_3
# Aligning image
# 2.00 3 40
# no exception
# 2554.6625488767063 (423, 416) 423 416
# 39
# pupDiam=2.00_dF=+40Source_4
# Aligning image
# 2.00 4 40
# no exception
# 1576.1501477273102 (423, 414) 423 414
# 40
# pupDiam=2.00_dF=+30Source_1
# Aligning image
# 2.00 1 30
# no exception
# 3270.8547037003864 (423, 423) 423 423
# 41
# pupDiam=2.00_dF=+30Source_2
# Aligning image
# 2.00 2 30
# no exception
# 3383.355875560397 (423, 420) 423 420
# 42
# pupDiam=2.00_dF=+30Source_3
# Aligning image
# 2.00 3 30
# no exception
# 3045.391679917665 (423, 417) 423 417
# 43
# pupDiam=2.00_dF=+30Source_4
# Aligning image
# 2.00 4 30
# no exception
# 1909.3084364851472 (423, 416) 423 416
# 44
# pupDiam=2.00_dF=+20Source_1
# Aligning image
# 2.00 1 20
# no exception
# 3424.205912478342 (423, 423) 423 423
# 45
# pupDiam=2.00_dF=+20Source_2
# Aligning image
# 2.00 2 20
# no exception
# 3703.8592465606607 (423, 421) 423 421
# 46
# pupDiam=2.00_dF=+20Source_3
# Aligning image
# 2.00 3 20
# no exception
# 3758.5522677277 (423, 419) 423 419
# 47
# pupDiam=2.00_dF=+20Source_4
# Aligning image
# 2.00 4 20
# no exception
# 2291.479255430291 (423, 418) 423 418
# 48
# pupDiam=2.00_dF=+10Source_1
# Aligning image
# 2.00 1 10
# no exception
# 3790.1412164908966 (423, 423) 423 423
# 49
# pupDiam=2.00_dF=+10Source_2
# Aligning image
# 2.00 2 10
# no exception
# 4083.3653343317 (423, 421) 423 421
# 50
# pupDiam=2.00_dF=+10Source_3
# Aligning image
# 2.00 3 10
# no exception
# 4096.486557258391 (423, 420) 423 420
# 51
# pupDiam=2.00_dF=+10Source_4
# Aligning image
# 2.00 4 10
# no exception
# 2719.2722907817833 (423, 420) 423 420
# 52
# pupDiam=2.00_dF=+00Source_1
# Aligning image
# 2.00 1 0
# no exception
# 2758.7027658352654 (423, 423) 423 423
# 53
# pupDiam=2.00_dF=+00Source_2
# Aligning image
# 2.00 2 0
# no exception
# 3181.060966429251 (423, 422) 423 422
# 54
# pupDiam=2.00_dF=+00Source_3
# Aligning image
# 2.00 3 0
# no exception
# 3664.018104565875 (423, 422) 423 422
# 55
# pupDiam=2.00_dF=+00Source_4
# Aligning image
# 2.00 4 0
# no exception
# 3216.82728833338 (423, 422) 423 422
# 56
# pupDiam=2.00_dF=-10Source_1
# Aligning image
# 2.00 1 -10
# no exception
# 1883.8361143766447 (423, 423) 423 423
# 57
# pupDiam=2.00_dF=-10Source_2
# Aligning image
# 2.00 2 -10
# no exception
# 2121.768699295448 (423, 423) 423 423
# 58
# pupDiam=2.00_dF=-10Source_3
# Aligning image
# 2.00 3 -10
# no exception
# 2572.628440780429 (423, 424) 423 424
# 59
# pupDiam=2.00_dF=-10Source_4
# Aligning image
# 2.00 4 -10
# no exception
# 2663.104166356202 (423, 424) 423 424
# 60
# pupDiam=2.00_dF=-20Source_1
# Aligning image
# 2.00 1 -20
# no exception
# 1333.3182823407046 (423, 422) 423 422
# 61
# pupDiam=2.00_dF=-20Source_2
# Aligning image
# 2.00 2 -20
# no exception
# 1425.851205414219 (423, 424) 423 424
# 62
# pupDiam=2.00_dF=-20Source_3
# Aligning image
# 2.00 3 -20
# no exception
# 1740.4402462741277 (423, 425) 423 425
# 63
# pupDiam=2.00_dF=-20Source_4
# Aligning image
# 2.00 4 -20
# no exception
# 1963.7735763448072 (423, 426) 423 426
# 64
# pupDiam=2.00_dF=-30Source_1
# Aligning image
# 2.00 1 -30
# no exception
# 1035.7696528298454 (423, 422) 423 422
# 65
# pupDiam=2.00_dF=-30Source_2
# Aligning image
# 2.00 2 -30
# no exception
# 1057.5027316668234 (424, 423) 424 423
# 66
# pupDiam=2.00_dF=-30Source_3
# Aligning image
# 2.00 3 -30
# exception
# 322.88093936293507 (423, 427) 423 427
# 67
# pupDiam=2.00_dF=-30Source_4
# Aligning image
# 2.00 4 -30
# no exception
# 1396.1141711465116 (423, 428) 423 428
# 68
# pupDiam=2.00_dF=-40Source_1
# Aligning image
# 2.00 1 -40
# no exception
# 861.615367174109 (423, 422) 423 422
# 69
# pupDiam=2.00_dF=-40Source_2
# Aligning image
# 2.00 2 -40
# no exception
# 879.4208968404386 (425, 422) 425 422
# 70
# pupDiam=2.00_dF=-40Source_3
# Aligning image
# 2.00 3 -40
# exception
# 366.56268879735046 (423, 428) 423 428
# 71
# pupDiam=2.00_dF=-40Source_4
# Aligning image
# 2.00 4 -40
# no exception
# 1053.7106484100177 (423, 430) 423 430
# 0
# pupDiam=1.40_dF=+40Source_1
# Aligning image
# 1.40 1 40
# no exception
# 1456.9191646062147 (422, 422) 422 422
# 1
# pupDiam=1.40_dF=+40Source_2
# Aligning image
# 1.40 2 40
# exception
# 620.2407519361793 (422, 422) 422 422
# 2
# pupDiam=1.40_dF=+40Source_3
# Aligning image
# 1.40 3 40
# no exception
# 1391.2892385008122 (423, 417) 423 417
# 3
# pupDiam=1.40_dF=+40Source_4
# Aligning image
# 1.40 4 40
# no exception
# 1320.4742246967623 (423, 417) 423 417
# 4
# pupDiam=1.40_dF=+30Source_1
# Aligning image
# 1.40 1 30
# no exception
# 2159.8664223495202 (423, 423) 423 423
# 5
# pupDiam=1.40_dF=+30Source_2
# Aligning image
# 1.40 2 30
# exception
# 866.4629274640313 (423, 420) 423 420
# 6
# pupDiam=1.40_dF=+30Source_3
# Aligning image
# 1.40 3 30
# no exception
# 1576.4960411109055 (423, 418) 423 418
# 7
# pupDiam=1.40_dF=+30Source_4
# Aligning image
# 1.40 4 30
# no exception
# 1426.452506203288 (423, 418) 423 418
# 8
# pupDiam=1.40_dF=+20Source_1
# Aligning image
# 1.40 1 20
# no exception
# 2747.7867045011703 (423, 423) 423 423
# 9
# pupDiam=1.40_dF=+20Source_2
# Aligning image
# 1.40 2 20
# exception
# 1186.6531342276846 (423, 420) 423 420
# 10
# pupDiam=1.40_dF=+20Source_3
# Aligning image
# 1.40 3 20
# no exception
# 1750.8707651063528 (423, 419) 423 419
# 11
# pupDiam=1.40_dF=+20Source_4
# Aligning image
# 1.40 4 20
# no exception
# 1536.869678976997 (423, 420) 423 420
# 12
# pupDiam=1.40_dF=+10Source_1
# Aligning image
# 1.40 1 10
# no exception
# 2784.5708720784705 (423, 423) 423 423
# 13
# pupDiam=1.40_dF=+10Source_2
# Aligning image
# 1.40 2 10
# exception
# 1430.3938846196188 (423, 421) 423 421
# 14
# pupDiam=1.40_dF=+10Source_3
# Aligning image
# 1.40 3 10
# no exception
# 1936.1536815938198 (423, 421) 423 421
# 15
# pupDiam=1.40_dF=+10Source_4
# Aligning image
# 1.40 4 10
# no exception
# 1637.3719078480271 (423, 421) 423 421
# 16
# pupDiam=1.40_dF=+00Source_1
# Aligning image
# 1.40 1 0
# no exception
# 2085.6276876891366 (423, 423) 423 423
# 17
# pupDiam=1.40_dF=+00Source_2
# Aligning image
# 1.40 2 0
# exception
# 1196.1881585604235 (423, 422) 423 422
# 18
# pupDiam=1.40_dF=+00Source_3
# Aligning image
# 1.40 3 0
# no exception
# 1912.9426924975214 (423, 422) 423 422
# 19
# pupDiam=1.40_dF=+00Source_4
# Aligning image
# 1.40 4 0
# no exception
# 1674.339016061283 (423, 424) 423 424
# 20
# pupDiam=1.40_dF=-10Source_1
# Aligning image
# 1.40 1 -10
# no exception
# 1395.3183200510239 (423, 423) 423 423
# 21
# pupDiam=1.40_dF=-10Source_2
# Aligning image
# 1.40 2 -10
# exception
# 711.7075801579022 (423, 423) 423 423
# 22
# pupDiam=1.40_dF=-10Source_3
# Aligning image
# 1.40 3 -10
# no exception
# 1547.274914365581 (423, 424) 423 424
# 23
# pupDiam=1.40_dF=-10Source_4
# Aligning image
# 1.40 4 -10
# no exception
# 1471.8188673336836 (423, 426) 423 426
# 24
# pupDiam=1.40_dF=-20Source_1
# Aligning image
# 1.40 1 -20
# no exception
# 962.8914110634915 (423, 423) 423 423
# 25
# pupDiam=1.40_dF=-20Source_2
# Aligning image
# 1.40 2 -20
# exception
# 415.3294179021532 (423, 424) 423 424
# 26
# pupDiam=1.40_dF=-20Source_3
# Aligning image
# 1.40 3 -20
# no exception
# 1146.9768722375595 (423, 426) 423 426
# 27
# pupDiam=1.40_dF=-20Source_4
# Aligning image
# 1.40 4 -20
# no exception
# 1207.4182369492266 (423, 428) 423 428
# 28
# pupDiam=1.40_dF=-30Source_1
# Aligning image
# 1.40 1 -30
# no exception
# 710.16876869194 (423, 422) 423 422
# 29
# pupDiam=1.40_dF=-30Source_2
# Aligning image
# 1.40 2 -30
# exception
# 263.81857083116887 (423, 425) 423 425
# 30
# pupDiam=1.40_dF=-30Source_3
# Aligning image
# 1.40 3 -30
# exception
# 207.10411470526026 (423, 428) 423 428
# 31
# pupDiam=1.40_dF=-30Source_4
# Aligning image
# 1.40 4 -30
# no exception
# 979.6311100474777 (423, 430) 423 430
# 32
# pupDiam=1.40_dF=-40Source_1
# Aligning image
# 1.40 1 -40
# exception
# 128.10783152621622 (422, 422) 422 422
# 33
# pupDiam=1.40_dF=-40Source_2
# Aligning image
# 1.40 2 -40
# no exception
# 601.9139700557232 (422, 425) 422 425
# 34
# pupDiam=1.40_dF=-40Source_3
# Aligning image
# 1.40 3 -40
# exception
# 135.39875441412863 (423, 431) 423 431
# 35
# pupDiam=1.40_dF=-40Source_4
# Aligning image
# 1.40 4 -40
# exception
# 320.5579190621778 (423, 432) 423 432
# 36
# pupDiam=2.00_dF=+40Source_1
# Aligning image
# 2.00 1 40
# no exception
# 1342.573727769819 (423, 423) 423 423
# 37
# pupDiam=2.00_dF=+40Source_2
# Aligning image
# 2.00 2 40
# no exception
# 1384.1745058979654 (423, 419) 423 419
# 38
# pupDiam=2.00_dF=+40Source_3
# Aligning image
# 2.00 3 40
# no exception
# 1173.533784388426 (423, 416) 423 416
# 39
# pupDiam=2.00_dF=+40Source_4
# Aligning image
# 2.00 4 40
# no exception
# 744.8794686523293 (423, 415) 423 415
# 40
# pupDiam=2.00_dF=+30Source_1
# Aligning image
# 2.00 1 30
# no exception
# 1400.132695093124 (423, 423) 423 423
# 41
# pupDiam=2.00_dF=+30Source_2
# Aligning image
# 2.00 2 30
# no exception
# 1464.7843502537723 (423, 420) 423 420
# 42
# pupDiam=2.00_dF=+30Source_3
# Aligning image
# 2.00 3 30
# no exception
# 1326.727661624787 (423, 418) 423 418
# 43
# pupDiam=2.00_dF=+30Source_4
# Aligning image
# 2.00 4 30
# no exception
# 848.9667527076556 (423, 416) 423 416
# 44
# pupDiam=2.00_dF=+20Source_1
# Aligning image
# 2.00 1 20
# no exception
# 1380.0425151953084 (423, 423) 423 423
# 45
# pupDiam=2.00_dF=+20Source_2
# Aligning image
# 2.00 2 20
# no exception
# 1530.4066380466472 (423, 421) 423 421
# 46
# pupDiam=2.00_dF=+20Source_3
# Aligning image
# 2.00 3 20
# no exception
# 1536.9326861845411 (423, 419) 423 419
# 47
# pupDiam=2.00_dF=+20Source_4
# Aligning image
# 2.00 4 20
# no exception
# 962.5520798099277 (423, 418) 423 418
# 48
# pupDiam=2.00_dF=+10Source_1
# Aligning image
# 2.00 1 10
# no exception
# 1444.5075185202884 (423, 423) 423 423
# 49
# pupDiam=2.00_dF=+10Source_2
# Aligning image
# 2.00 2 10
# no exception
# 1591.8487076502547 (423, 422) 423 422
# 50
# pupDiam=2.00_dF=+10Source_3
# Aligning image
# 2.00 3 10
# no exception
# 1584.539714301926 (423, 421) 423 421
# 51
# pupDiam=2.00_dF=+10Source_4
# Aligning image
# 2.00 4 10
# no exception
# 1080.7766107866055 (423, 420) 423 420
# 52
# pupDiam=2.00_dF=+00Source_1
# Aligning image
# 2.00 1 0
# no exception
# 1102.3120562583872 (423, 423) 423 423
# 53
# pupDiam=2.00_dF=+00Source_2
# Aligning image
# 2.00 2 0
# no exception
# 1246.9973228396268 (423, 422) 423 422
# 54
# pupDiam=2.00_dF=+00Source_3
# Aligning image
# 2.00 3 0
# no exception
# 1427.9333363864707 (423, 422) 423 422
# 55
# pupDiam=2.00_dF=+00Source_4
# Aligning image
# 2.00 4 0
# no exception
# 1209.634158013533 (423, 422) 423 422
# 56
# pupDiam=2.00_dF=-10Source_1
# Aligning image
# 2.00 1 -10
# no exception
# 823.8179312417415 (423, 423) 423 423
# 57
# pupDiam=2.00_dF=-10Source_2
# Aligning image
# 2.00 2 -10
# no exception
# 903.9389317814583 (423, 423) 423 423
# 58
# pupDiam=2.00_dF=-10Source_3
# Aligning image
# 2.00 3 -10
# no exception
# 1082.9318063745309 (423, 424) 423 424
# 59
# pupDiam=2.00_dF=-10Source_4
# Aligning image
# 2.00 4 -10
# no exception
# 1023.9621873694191 (423, 424) 423 424
# 60
# pupDiam=2.00_dF=-20Source_1
# Aligning image
# 2.00 1 -20
# no exception
# 640.2892252895901 (423, 422) 423 422
# 61
# pupDiam=2.00_dF=-20Source_2
# Aligning image
# 2.00 2 -20
# no exception
# 671.0904648946456 (423, 424) 423 424
# 62
# pupDiam=2.00_dF=-20Source_3
# Aligning image
# 2.00 3 -20
# no exception
# 794.7001282444984 (423, 425) 423 425
# 63
# pupDiam=2.00_dF=-20Source_4
# Aligning image
# 2.00 4 -20
# no exception
# 804.4517591872111 (423, 426) 423 426
# 64
# pupDiam=2.00_dF=-30Source_1
# Aligning image
# 2.00 1 -30
# no exception
# 530.6715480090072 (423, 422) 423 422
# 65
# pupDiam=2.00_dF=-30Source_2
# Aligning image
# 2.00 2 -30
# no exception
# 536.3918304492248 (423, 423) 423 423
# 66
# pupDiam=2.00_dF=-30Source_3
# Aligning image
# 2.00 3 -30
# exception
# 109.80574419541534 (423, 427) 423 427
# 67
# pupDiam=2.00_dF=-30Source_4
# Aligning image
# 2.00 4 -30
# no exception
# 626.790313360305 (423, 428) 423 428
# 68
# pupDiam=2.00_dF=-40Source_1
# Aligning image
# 2.00 1 -40
# no exception
# 459.8722857449325 (422, 422) 422 422
# 69
# pupDiam=2.00_dF=-40Source_2
# Aligning image
# 2.00 2 -40
# no exception
# 462.5829994229776 (422, 422) 422 422
# 70
# pupDiam=2.00_dF=-40Source_3
# Aligning image
# 2.00 3 -40
# exception
# 152.9374377528625 (423, 428) 423 428
# 71
# pupDiam=2.00_dF=-40Source_4
# Aligning image
# 2.00 4 -40
# no exception
# 514.7455757286056 (423, 430) 423 430
# 0
# pupDiam=1.40_dF=+40Source_1
# Aligning image
# 1.40 1 40
# no exception
# 8774.982191980564 (422, 423) 422 423
# 1
# pupDiam=1.40_dF=+40Source_2
# Aligning image
# 1.40 2 40
# exception
# 3470.54004953402 (422, 421) 422 421
# 2
# pupDiam=1.40_dF=+40Source_3
# Aligning image
# 1.40 3 40
# no exception
# 8378.380576804859 (423, 417) 423 417
# 3
# pupDiam=1.40_dF=+40Source_4
# Aligning image
# 1.40 4 40
# no exception
# 7974.02442200316 (423, 417) 423 417
# 4
# pupDiam=1.40_dF=+30Source_1
# Aligning image
# 1.40 1 30
# no exception
# 13386.278717375833 (423, 423) 423 423
# 5
# pupDiam=1.40_dF=+30Source_2
# Aligning image
# 1.40 2 30
# exception
# 5072.096818465497 (423, 420) 423 420
# 6
# pupDiam=1.40_dF=+30Source_3
# Aligning image
# 1.40 3 30
# no exception
# 9704.623649597343 (423, 418) 423 418
# 7
# pupDiam=1.40_dF=+30Source_4
# Aligning image
# 1.40 4 30
# no exception
# 8775.010114621404 (423, 418) 423 418
# 8
# pupDiam=1.40_dF=+20Source_1
# Aligning image
# 1.40 1 20
# no exception
# 16650.364848561592 (423, 423) 423 423
# 9
# pupDiam=1.40_dF=+20Source_2
# Aligning image
# 1.40 2 20
# exception
# 6896.1955754909495 (423, 420) 423 420
# 10
# pupDiam=1.40_dF=+20Source_3
# Aligning image
# 1.40 3 20
# no exception
# 10813.524622122128 (423, 419) 423 419
# 11
# pupDiam=1.40_dF=+20Source_4
# Aligning image
# 1.40 4 20
# no exception
# 9460.17247859109 (423, 420) 423 420
# 12
# pupDiam=1.40_dF=+10Source_1
# Aligning image
# 1.40 1 10
# no exception
# 16069.76834145248 (423, 423) 423 423
# 13
# pupDiam=1.40_dF=+10Source_2
# Aligning image
# 1.40 2 10
# exception
# 7618.676808970921 (423, 421) 423 421
# 14
# pupDiam=1.40_dF=+10Source_3
# Aligning image
# 1.40 3 10
# no exception
# 11494.448122156062 (423, 420) 423 420
# 15
# pupDiam=1.40_dF=+10Source_4
# Aligning image
# 1.40 4 10
# no exception
# 9839.425938648254 (423, 421) 423 421
# 16
# pupDiam=1.40_dF=+00Source_1
# Aligning image
# 1.40 1 0
# no exception
# 11815.994480970585 (423, 423) 423 423
# 17
# pupDiam=1.40_dF=+00Source_2
# Aligning image
# 1.40 2 0
# exception
# 6074.68573921811 (423, 422) 423 422
# 18
# pupDiam=1.40_dF=+00Source_3
# Aligning image
# 1.40 3 0
# no exception
# 10678.36089081741 (423, 422) 423 422
# 19
# pupDiam=1.40_dF=+00Source_4
# Aligning image
# 1.40 4 0
# no exception
# 9672.595388067692 (423, 423) 423 423
# 20
# pupDiam=1.40_dF=-10Source_1
# Aligning image
# 1.40 1 -10
# no exception
# 8058.247211101649 (423, 423) 423 423
# 21
# pupDiam=1.40_dF=-10Source_2
# Aligning image
# 1.40 2 -10
# exception
# 3863.157359467403 (423, 423) 423 423
# 22
# pupDiam=1.40_dF=-10Source_3
# Aligning image
# 1.40 3 -10
# no exception
# 8762.843418554927 (423, 424) 423 424
# 23
# pupDiam=1.40_dF=-10Source_4
# Aligning image
# 1.40 4 -10
# no exception
# 8322.732863595247 (423, 425) 423 425
# 24
# pupDiam=1.40_dF=-20Source_1
# Aligning image
# 1.40 1 -20
# no exception
# 5388.19211474238 (423, 423) 423 423
# 25
# pupDiam=1.40_dF=-20Source_2
# Aligning image
# 1.40 2 -20
# exception
# 2316.3595353728906 (423, 424) 423 424
# 26
# pupDiam=1.40_dF=-20Source_3
# Aligning image
# 1.40 3 -20
# no exception
# 6823.425958211499 (423, 425) 423 425
# 27
# pupDiam=1.40_dF=-20Source_4
# Aligning image
# 1.40 4 -20
# no exception
# 7017.797946265246 (423, 427) 423 427
# 28
# pupDiam=1.40_dF=-30Source_1
# Aligning image
# 1.40 1 -30
# no exception
# 3674.857403127308 (423, 423) 423 423
# 29
# pupDiam=1.40_dF=-30Source_2
# Aligning image
# 1.40 2 -30
# exception
# 1422.8238092212093 (423, 426) 423 426
# 30
# pupDiam=1.40_dF=-30Source_3
# Aligning image
# 1.40 3 -30
# exception
# 1090.8453757580137 (423, 428) 423 428
# 31
# pupDiam=1.40_dF=-30Source_4
# Aligning image
# 1.40 4 -30
# no exception
# 5831.870885875059 (423, 429) 423 429
# 32
# pupDiam=1.40_dF=-40Source_1
# Aligning image
# 1.40 1 -40
# exception
# 596.2981485709741 (423, 423) 423 423
# 33
# pupDiam=1.40_dF=-40Source_2
# Aligning image
# 1.40 2 -40
# no exception
# 3150.7732827039636 (423, 427) 423 427
# 34
# pupDiam=1.40_dF=-40Source_3
# Aligning image
# 1.40 3 -40
# exception
# 699.7301526758943 (423, 430) 423 430
# 35
# pupDiam=1.40_dF=-40Source_4
# Aligning image
# 1.40 4 -40
# exception
# 1815.5775216482725 (423, 431) 423 431
# 36
# pupDiam=2.00_dF=+40Source_1
# Aligning image
# 2.00 1 40
# no exception
# 7959.587207642193 (423, 423) 423 423
# 37
# pupDiam=2.00_dF=+40Source_2
# Aligning image
# 2.00 2 40
# no exception
# 8242.92231933895 (423, 419) 423 419
# 38
# pupDiam=2.00_dF=+40Source_3
# Aligning image
# 2.00 3 40
# no exception
# 6961.002519421588 (423, 416) 423 416
# 39
# pupDiam=2.00_dF=+40Source_4
# Aligning image
# 2.00 4 40
# no exception
# 4212.764269825599 (423, 415) 423 415
# 40
# pupDiam=2.00_dF=+30Source_1
# Aligning image
# 2.00 1 30
# no exception
# 8357.255508545173 (423, 423) 423 423
# 41
# pupDiam=2.00_dF=+30Source_2
# Aligning image
# 2.00 2 30
# no exception
# 8944.555932473662 (423, 420) 423 420
# 42
# pupDiam=2.00_dF=+30Source_3
# Aligning image
# 2.00 3 30
# no exception
# 8114.672308841416 (423, 417) 423 417
# 43
# pupDiam=2.00_dF=+30Source_4
# Aligning image
# 2.00 4 30
# no exception
# 4991.944035062963 (423, 416) 423 416
# 44
# pupDiam=2.00_dF=+20Source_1
# Aligning image
# 2.00 1 20
# no exception
# 8126.358772482255 (423, 423) 423 423
# 45
# pupDiam=2.00_dF=+20Source_2
# Aligning image
# 2.00 2 20
# no exception
# 9247.448529055651 (423, 421) 423 421
# 46
# pupDiam=2.00_dF=+20Source_3
# Aligning image
# 2.00 3 20
# no exception
# 9275.133409962036 (423, 419) 423 419
# 47
# pupDiam=2.00_dF=+20Source_4
# Aligning image
# 2.00 4 20
# no exception
# 5752.627187671506 (423, 418) 423 418
# 48
# pupDiam=2.00_dF=+10Source_1
# Aligning image
# 2.00 1 10
# no exception
# 8095.060520253411 (423, 423) 423 423
# 49
# pupDiam=2.00_dF=+10Source_2
# Aligning image
# 2.00 2 10
# no exception
# 9092.825332975453 (423, 422) 423 422
# 50
# pupDiam=2.00_dF=+10Source_3
# Aligning image
# 2.00 3 10
# no exception
# 9198.895971743228 (423, 420) 423 420
# 51
# pupDiam=2.00_dF=+10Source_4
# Aligning image
# 2.00 4 10
# no exception
# 6355.818896533629 (423, 420) 423 420
# 52
# pupDiam=2.00_dF=+00Source_1
# Aligning image
# 2.00 1 0
# no exception
# 5972.60839711467 (423, 423) 423 423
# 53
# pupDiam=2.00_dF=+00Source_2
# Aligning image
# 2.00 2 0
# no exception
# 6903.898392836114 (423, 422) 423 422
# 54
# pupDiam=2.00_dF=+00Source_3
# Aligning image
# 2.00 3 0
# no exception
# 7871.513314900288 (423, 422) 423 422
# 55
# pupDiam=2.00_dF=+00Source_4
# Aligning image
# 2.00 4 0
# no exception
# 6708.895390120453 (423, 422) 423 422
# 56
# pupDiam=2.00_dF=-10Source_1
# Aligning image
# 2.00 1 -10
# no exception
# 4494.495127753951 (423, 423) 423 423
# 57
# pupDiam=2.00_dF=-10Source_2
# Aligning image
# 2.00 2 -10
# no exception
# 5030.740112213778 (423, 423) 423 423
# 58
# pupDiam=2.00_dF=-10Source_3
# Aligning image
# 2.00 3 -10
# no exception
# 6016.176861024238 (423, 424) 423 424
# 59
# pupDiam=2.00_dF=-10Source_4
# Aligning image
# 2.00 4 -10
# no exception
# 5477.78542507922 (423, 424) 423 424
# 60
# pupDiam=2.00_dF=-20Source_1
# Aligning image
# 2.00 1 -20
# no exception
# 3347.764849442743 (423, 423) 423 423
# 61
# pupDiam=2.00_dF=-20Source_2
# Aligning image
# 2.00 2 -20
# no exception
# 3599.7885884611514 (423, 424) 423 424
# 62
# pupDiam=2.00_dF=-20Source_3
# Aligning image
# 2.00 3 -20
# no exception
# 4422.076851374562 (423, 425) 423 425
# 63
# pupDiam=2.00_dF=-20Source_4
# Aligning image
# 2.00 4 -20
# no exception
# 4380.612030723702 (423, 426) 423 426
# 64
# pupDiam=2.00_dF=-30Source_1
# Aligning image
# 2.00 1 -30
# no exception
# 2561.635716750314 (423, 423) 423 423
# 65
# pupDiam=2.00_dF=-30Source_2
# Aligning image
# 2.00 2 -30
# no exception
# 2657.0275171294534 (423, 425) 423 425
# 66
# pupDiam=2.00_dF=-30Source_3
# Aligning image
# 2.00 3 -30
# exception
# 544.5605460822345 (423, 427) 423 427
# 67
# pupDiam=2.00_dF=-30Source_4
# Aligning image
# 2.00 4 -30
# no exception
# 3382.9474968247096 (423, 428) 423 428
# 68
# pupDiam=2.00_dF=-40Source_1
# Aligning image
# 2.00 1 -40
# no exception
# 2044.6216167595815 (423, 422) 423 422
# 69
# pupDiam=2.00_dF=-40Source_2
# Aligning image
# 2.00 2 -40
# no exception
# 2089.7492301846614 (423, 425) 423 425
# 70
# pupDiam=2.00_dF=-40Source_3
# Aligning image
# 2.00 3 -40
# exception
# 775.8065358523074 (423, 428) 423 428
# 71
# pupDiam=2.00_dF=-40Source_4
# Aligning image
# 2.00 4 -40
# no exception
# 2654.517603564083 (423, 430) 423 430
# Done!

# %% [raw]
# save_path = rootF + '/Documents/Myopia/Data analysis/Eye simulations/' + simulation + '_XYshifts_0deg_all_params_image1'
#
# shifts_in_um = shifts * 3.5
#
# np.savez(save_path + ".npz", shifts = shifts_in_um, PSFname = PSFname)
